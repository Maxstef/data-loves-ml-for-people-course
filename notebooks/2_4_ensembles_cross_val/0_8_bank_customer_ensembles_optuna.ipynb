# %% [markdown]
# # Bank Customer Churn Prediction (part 5 - ensembles and optuna)
#
# Link to part 4 - https://github.com/Maxstef/data-loves-ml-for-people-course/blob/main/notebooks/2_4_ensembles_cross_val/0_2_bank_customer_searchcv.ipynb

# %% [markdown]
# ## Imports & Files downloads

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline

import pandas as pd
import numpy as np

from mlpeople.io.google_drive import download_file_iss

# download files from google drive
download_file_iss('1Xz-cqp6y-Y_oCiaSJeNsbU3-o5lM-5wY', output_path='./downloads/train.csv')
download_file_iss('1jsg2iPVphDMiHCEyqQeDSc4yDcMB3-r_', output_path='./downloads/test.csv')
download_file_iss('1tv0beG2n8cUQ6KcdaXhFzQI_Fd9640gg', output_path='./downloads/sample_submission.csv')

# read train.csv / show first 5 rows / show info
raw_df = pd.read_csv('downloads/train.csv', index_col=0)
target_col = "Exited"
raw_df.head()
# Out:
#     CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# id
# 0   15779985.0   Nwankwo        678.0    France    Male  29.0     4.0
# 1   15650086.0     Ch'in        687.0    France  Female  34.0     1.0
# 2   15733602.0  Thompson        682.0    France  Female  52.0     6.0
# 3   15645794.0   Macleod        753.0   Germany    Male  44.0     6.0
# 4   15633840.0      Hsia        544.0   Germany  Female  55.0     0.0
#
#       Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# id
# 0        0.00            3.0        1.0             0.0        180626.36
# 1        0.00            2.0        0.0             1.0         63736.17
# 2        0.00            3.0        0.0             0.0        179655.87
# 3    83347.25            2.0        1.0             0.0        161407.48
# 4   107747.57            1.0        1.0             0.0        176580.86
#
#     Exited
# id
# 0      0.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      1.0

# %% [markdown]
# ## Experiments Preparation

# %%
# raw data for experiments
X_raw = raw_df.drop([target_col, "CustomerId", "Surname"],axis=1)
y_raw = raw_df[target_col]

# previously it was determined that 20-40% is optimal for validataion data so n_splits=3 should be fine
skf = StratifiedKFold(n_splits=3, shuffle=False)

# %%
# Pipeline that includes previosly implemented preprocessing steps
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import OneHotEncoder

from mlpeople.preprocessing.transformers import (
    ColumnDropper,
    NumericBinaryFlagTransformer,
    CategoricalBinaryFlagTransformer,
    TopNCategoricalTransformer,
    NumericBinner,
)

numeric_selector = make_column_selector(dtype_include=np.number)
categorical_selector = make_column_selector(dtype_exclude=np.number)

numeric_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("poly_features", PolynomialFeatures(include_bias=False))
])

categorical_pipeline = Pipeline(
    [("encoder", OneHotEncoder(handle_unknown="ignore", sparse_output=False, drop="if_binary"))]
)

preprocessor = ColumnTransformer(
    [
        ("num", numeric_pipeline, numeric_selector),
        ("cat", categorical_pipeline, categorical_selector),
    ]
)

# default (example) pipeline
pipeline_base = Pipeline([
    ("drop_cols", ColumnDropper([])),
    ("num_flags", NumericBinaryFlagTransformer({})),
    ("num_bin", NumericBinner({})),
    ("cat_flags", CategoricalBinaryFlagTransformer({})),
    ("top_n", TopNCategoricalTransformer({})),
    ("preprocessing", preprocessor),
    ("model", LogisticRegression(solver='liblinear'))
])

# %%
# helper function to display cv search result
def display_cv_result(
    cv_results,
    view_params=[],
    view_count=10
):
    result_df = pd.DataFrame(cv_results)
    view_params.extend([
        "mean_test_score",
        "std_test_score",
        "rank_test_score",
    ])
    result_df_view = result_df[
        view_params
    ].sort_values("mean_test_score", ascending=False)

    with pd.option_context('display.max_colwidth', None):
        display(
            result_df_view.head(view_count)
        )

# %% [markdown]
# ## Best previous

# %%
from math import inf

# best config for CategoricalBinaryFlagTransformer
cat_flag_is_germany = {
    "flag_name": "IsGermany",
    "value": "Germany",
    "drop_original": True
}
cat_flags_config_default = {
    "Geography": [cat_flag_is_germany]
}
# for further experiments
cat_flag_is_spain = {
    "flag_name": "IsSpain",
    "value": "Spain",
    "drop_original": True
}
cat_flag_is_france = {
    "flag_name": "IsFrance",
    "value": "France",
    "drop_original": True
}

# best config for NumericBinner transformer
num_bin_salary = {
    "bins": [0, 25000, 100000, inf],
    "labels": ["low", "medium", "high"],
    "new_col": "SalaryScore",
    "drop_original": True
}
num_bin_credit_score = {
    "bins": [0, 675, inf],
    "labels": ["low", "high"],
    "new_col": "CreditScoreScore",
    "drop_original": True
}
num_bin_mapping_default = {
    "EstimatedSalary": num_bin_salary,
    "CreditScore": num_bin_credit_score,
}

pipeline_prev_best = Pipeline([
    ("drop_cols", ColumnDropper(["Tenure", "HasCrCard"])),
    ("num_flags", NumericBinaryFlagTransformer({})),
    ("num_bin", NumericBinner(num_bin_mapping_default)),
    ("cat_flags", CategoricalBinaryFlagTransformer(cat_flags_config_default)),
    ("top_n", TopNCategoricalTransformer({})),
    ("preprocessing", preprocessor),
    ("model", LogisticRegression(solver='liblinear'))
])

# %%
grid_search_prev_best = GridSearchCV(
    pipeline_prev_best,
    {
        "drop_cols__columns": [
            ["Tenure", "HasCrCard"],
        ],
        "preprocessing__num__poly_features__degree": [3],
        "model__C": [0.3, 0.5],
        "model__l1_ratio": [1.0],
    },
    cv=skf,
    scoring="roc_auc",
)

grid_search_prev_best.fit(X_raw, y_raw)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('drop_cols',
#                                         ColumnDropper(columns=['Tenure',
#                                                                'HasCrCard'])),
#                                        ('num_flags',
#                                         NumericBinaryFlagTransformer(flag_config={})),
#                                        ('num_bin',
#                                         NumericBinner(mapping={'CreditScore': {'bins': [0,
#                                                                                         675,
#                                                                                         inf],
#                                                                                'drop_original': True,
#                                                                                'labels': ['low',
#                                                                                           'high'],
#                                                                                'new_col': 'Credi...
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x112e63710>)])),
#                                        ('model',
#                                         LogisticRegression(solver='liblinear'))]),
#              param_grid={'drop_cols__columns': [['Tenure', 'HasCrCard']],
#                          'model__C': [0.3, 0.5], 'model__l1_ratio': [1.0],
#                          'preprocessing__num__poly_features__degree': [3]},
#              scoring='roc_auc')

# %%
display_cv_result(
    grid_search_prev_best.cv_results_,
    view_params=[
        "param_model__l1_ratio",
        "param_model__C",
    ]
)
# Out:
#    param_model__l1_ratio  param_model__C  mean_test_score  std_test_score  \
# 0                    1.0             0.3         0.936473        0.000665
# 1                    1.0             0.5         0.936454        0.000765
#
#    rank_test_score
# 0                1
# 1                2

# %%
best_lg_model_pipeline = grid_search_prev_best.best_estimator_
best_lg_model_pipeline
# Out:
# Pipeline(steps=[('drop_cols', ColumnDropper(columns=['Tenure', 'HasCrCard'])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin',
#                  NumericBinner(mapping={'CreditScore': {'bins': [0, 675, inf],
#                                                         'drop_original': True,
#                                                         'labels': ['low',
#                                                                    'high'],
#                                                         'new_col': 'CreditScoreScore'},
#                                         'EstimatedSalary': {'bins': [0, 25000,
#                                                                      100000,
#                                                                      inf],
#                                                             'drop_original': True,
#                                                             'lab...
#                                                                                       include_bias=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x123a58470>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x123a5a0c0>)])),
#                 ('model',
#                  LogisticRegression(C=0.3, l1_ratio=1.0, solver='liblinear'))])

# %% [markdown]
# ## Random Forest

# %%
from sklearn.base import clone
from sklearn.ensemble import RandomForestClassifier

# start with previous best pipelein copy
pipeline_rf = clone(pipeline_prev_best)

pipeline_rf.set_params(
    model=RandomForestClassifier(
        n_estimators=100,
        max_depth=None,
        random_state=42,
        n_jobs=-1,
    )
)
# Out:
# Pipeline(steps=[('drop_cols', ColumnDropper(columns=['Tenure', 'HasCrCard'])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin',
#                  NumericBinner(mapping={'CreditScore': {'bins': [0, 675, inf],
#                                                         'drop_original': True,
#                                                         'labels': ['low',
#                                                                    'high'],
#                                                         'new_col': 'CreditScoreScore'},
#                                         'EstimatedSalary': {'bins': [0, 25000,
#                                                                      100000,
#                                                                      inf],
#                                                             'drop_original': True,
#                                                             'lab...
#                                                                    PolynomialFeatures(include_bias=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x123a79730>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x123a78620>)])),
#                 ('model', RandomForestClassifier(n_jobs=-1, random_state=42))])

# %% [markdown]
# ### Drop cols & Poly degree & Custom flags

# %%
# %%time

# some combinations of param options might cause error
import warnings
warnings.filterwarnings('ignore')

cat_flags_config_all_options = [
    {}, 
    cat_flags_config_default,
    {
        "Geography": [cat_flag_is_germany, cat_flag_is_france]
    },
    {
        "Geography": [cat_flag_is_germany, cat_flag_is_spain]
    },
    {
        "Geography": [cat_flag_is_germany, cat_flag_is_spain, cat_flag_is_france]
    },
]

num_bin_mapping_all_options = [
    {},
    num_bin_mapping_default,
    {
        "EstimatedSalary": num_bin_salary,
    },
    {
        "CreditScore": num_bin_credit_score,
    }
]


random_search_rf_drop_poly = RandomizedSearchCV(
    pipeline_rf,
    {
        "drop_cols__columns": [
            [],
            ["Tenure"],
            ["Tenure", "HasCrCard"],
            ["Tenure", "HasCrCard", "EstimatedSalary"],
            ["Tenure", "HasCrCard", "CreditScore"],
            ["Tenure", "HasCrCard", "EstimatedSalary", "CreditScore"],
        ],
        "preprocessing__num__poly_features__degree": [1, 2, 3],
        "preprocessing__cat__encoder__drop": ["if_binary", None],
        "cat_flags__flag_config": cat_flags_config_all_options,
        "num_bin__mapping": num_bin_mapping_all_options,
    },
    cv=skf,
    scoring="roc_auc",
    n_iter=80,
)

random_search_rf_drop_poly.fit(X_raw, y_raw)
# Out:
# CPU times: user 2min 57s, sys: 4.79 s, total: 3min 2s
# Wall time: 33.4 s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('drop_cols',
#                                               ColumnDropper(columns=['Tenure',
#                                                                      'HasCrCard'])),
#                                              ('num_flags',
#                                               NumericBinaryFlagTransformer(flag_config={})),
#                                              ('num_bin',
#                                               NumericBinner(mapping={'CreditScore': {'bins': [0,
#                                                                                               675,
#                                                                                               inf],
#                                                                                      'drop_original': True,
#                                                                                      'labels': ['low',
#                                                                                                 'high'],
#                                                                                      'new_col':...
#                                                              {'EstimatedSalary': {'bins': [0,
#                                                                                            25000,
#                                                                                            100000,
#                                                                                            inf],
#                                                                                   'drop_original': True,
#                                                                                   'labels': ['low',
#                                                                                              'medium',
#                                                                                              'high'],
#                                                                                   'new_col': 'SalaryScore'}},
#                                                              {'CreditScore': {'bins': [0,
#                                                                                        675,
#                                                                                        inf],
#                                                                               'drop_original': True,
#                                                                               'labels': ['low',
#                                                                                          'high'],
#                                                                               'new_col': 'CreditScoreScore'}}],
#                                         'preprocessing__cat__encoder__drop': ['if_binary',
#                                                                               None],
#                                         'preprocessing__num__poly_features__degree': [1,
#                                                                                       2,
#                                                                                       3]},
#                    scoring='roc_auc')

# %%
display_cv_result(
    random_search_rf_drop_poly.cv_results_,
    view_params=[
        "param_drop_cols__columns",
        "param_preprocessing__num__poly_features__degree",
        "param_preprocessing__cat__encoder__drop",
        "param_cat_flags__flag_config",
        "param_num_bin__mapping",
    ],
    view_count=15,
)
# Out:
#    param_drop_cols__columns  param_preprocessing__num__poly_features__degree  \
# 59                       []                                                2
# 27                       []                                                1
# 52                       []                                                2
# 39      [Tenure, HasCrCard]                                                2
# 25                       []                                                2
# 26                       []                                                1
# 30      [Tenure, HasCrCard]                                                1
# 50                 [Tenure]                                                1
# 40                 [Tenure]                                                1
# 8       [Tenure, HasCrCard]                                                1
# 48      [Tenure, HasCrCard]                                                1
# 76      [Tenure, HasCrCard]                                                2
# 10                       []                                                3
# 62                       []                                                1
# 22      [Tenure, HasCrCard]                                                1
#
#    param_preprocessing__cat__encoder__drop  \
# 59                                    None
# 27                               if_binary
# 52                                    None
# 39                                    None
# 25                               if_binary
# 26                                    None
# 30                                    None
# 50                               if_binary
# 40                                    None
# 8                                if_binary
# 48                                    None
# 76                               if_binary
# 10                                    None
# 62                                    None
# 22                               if_binary
#
#                                                                                                                                                                                                       param_cat_flags__flag_config  \
# 59                                                                                                                                          {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}]}
# 27                                                                       {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsSpain', 'value': 'Spain', 'drop_original': True}]}
# 52                                                                       {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsSpain', 'value': 'Spain', 'drop_original': True}]}
# 39                                                                                                                                                                                                                              {}
# 25                                                                                                                                                                                                                              {}
# 26  {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsSpain', 'value': 'Spain', 'drop_original': True}, {'flag_name': 'IsFrance', 'value': 'France', 'drop_original': True}]}
# 30  {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsSpain', 'value': 'Spain', 'drop_original': True}, {'flag_name': 'IsFrance', 'value': 'France', 'drop_original': True}]}
# 50                                                                     {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsFrance', 'value': 'France', 'drop_original': True}]}
# 40                                                                     {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsFrance', 'value': 'France', 'drop_original': True}]}
# 8                                                                      {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsFrance', 'value': 'France', 'drop_original': True}]}
# 48                                                                                                                                          {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}]}
# 76  {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsSpain', 'value': 'Spain', 'drop_original': True}, {'flag_name': 'IsFrance', 'value': 'France', 'drop_original': True}]}
# 10                                                                                                                                          {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}]}
# 62  {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsSpain', 'value': 'Spain', 'drop_original': True}, {'flag_name': 'IsFrance', 'value': 'France', 'drop_original': True}]}
# 22                                                                       {'Geography': [{'flag_name': 'IsGermany', 'value': 'Germany', 'drop_original': True}, {'flag_name': 'IsSpain', 'value': 'Spain', 'drop_original': True}]}
#
#                                                                                                                           param_num_bin__mapping  \
# 59                                                                                                                                            {}
# 27                                                                                                                                            {}
# 52                                                                                                                                            {}
# 39                                                                                                                                            {}
# 25                                                                                                                                            {}
# 26                                                                                                                                            {}
# 30                                                                                                                                            {}
# 50                                                                                                                                            {}
# 40                                                                                                                                            {}
# 8                                                                                                                                             {}
# 48                                                                                                                                            {}
# 76                                                                                                                                            {}
# 10  {'EstimatedSalary': {'bins': [0, 25000, 100000, inf], 'labels': ['low', 'medium', 'high'], 'new_col': 'SalaryScore', 'drop_original': True}}
# 62  {'EstimatedSalary': {'bins': [0, 25000, 100000, inf], 'labels': ['low', 'medium', 'high'], 'new_col': 'SalaryScore', 'drop_original': True}}
# 22                     {'CreditScore': {'bins': [0, 675, inf], 'labels': ['low', 'high'], 'new_col': 'CreditScoreScore', 'drop_original': True}}
#
#     mean_test_score  std_test_score  rank_test_score
# 59         0.923305        0.000776                1
# 27         0.923280        0.000819                2
# 52         0.922035        0.001284                3
# 39         0.921869        0.001219                4
# 25         0.921361        0.001271                5
# 26         0.921346        0.001504                6
# 30         0.921273        0.000704                7
# 50         0.921176        0.001384                8
# 40         0.921090        0.001967                9
# 8          0.920394        0.000717               10
# 48         0.920118        0.001233               11
# 76         0.919572        0.000206               12
# 10         0.918874        0.001175               13
# 62         0.916816        0.001506               14
# 22         0.916303        0.001002               15

# %%
# update random forest pipeline based on above result
pipeline_rf = Pipeline([
    ("drop_cols", ColumnDropper([])), # leave all cols
    ("num_flags", NumericBinaryFlagTransformer({})),
    ("num_bin", NumericBinner({})), # no custom num bin, leave cols as it is
    ("cat_flags", CategoricalBinaryFlagTransformer({
        "Geography": [cat_flag_is_germany, cat_flag_is_spain] # add spain here
    })),
    ("top_n", TopNCategoricalTransformer({})),
    ("preprocessing", preprocessor), # 2 degree is default for PolynomialFeatures
    ("model", RandomForestClassifier(
        n_estimators=100,
        max_depth=None,
        random_state=42,
        n_jobs=-1,
    ))
])

# %% [markdown]
# ### Hyperparams tuning - RandomizedSearchCV

# %%
# %%time

random_search_rf_hyper_tun = RandomizedSearchCV(
    pipeline_rf,
    {
        "model__n_estimators": range(10, 300, 10),
        "model__max_depth": range(3, 20, 2),
        "model__max_leaf_nodes": range(10, 2000, 10),
        "model__criterion": ["gini", "entropy"],
        "model__min_samples_split": range(2, 20),
        "model__min_samples_leaf": range(1, 10),
        "model__max_features": ["sqrt", "log2", 0.5, 0.8],
        "model__max_samples": [None, 0.6],
        "model__bootstrap": [True, False],
        "model__min_impurity_decrease": [0.0, 0.1],
        "model__class_weight": ["balanced", "balanced_subsample", {0.0: 1, 1.0: 5}, {0.0: 5, 1.0: 1}],
    },
    cv=skf,
    scoring="roc_auc",
    n_iter=80,
    random_state=42,
)

random_search_rf_hyper_tun.fit(X_raw, y_raw)
# Out:
# CPU times: user 17min 41s, sys: 16.6 s, total: 17min 57s
# Wall time: 2min 42s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('drop_cols',
#                                               ColumnDropper(columns=[])),
#                                              ('num_flags',
#                                               NumericBinaryFlagTransformer(flag_config={})),
#                                              ('num_bin',
#                                               NumericBinner(mapping={})),
#                                              ('cat_flags',
#                                               CategoricalBinaryFlagTransformer(flag_config={'Geography': [{'drop_original': True,
#                                                                                                            'flag_name'...
#                                         'model__criterion': ['gini', 'entropy'],
#                                         'model__max_depth': range(3, 20, 2),
#                                         'model__max_features': ['sqrt', 'log2',
#                                                                 0.5, 0.8],
#                                         'model__max_leaf_nodes': range(10, 2000, 10),
#                                         'model__max_samples': [None, 0.6],
#                                         'model__min_impurity_decrease': [0.0,
#                                                                          0.1],
#                                         'model__min_samples_leaf': range(1, 10),
#                                         'model__min_samples_split': range(2, 20),
#                                         'model__n_estimators': range(10, 300, 10)},
#                    random_state=42, scoring='roc_auc')

# %%
display_cv_result(
    random_search_rf_hyper_tun.cv_results_,
    view_params=[
        "param_model__n_estimators",
        "param_model__max_depth",
        "param_model__max_leaf_nodes",
        "param_model__criterion",
        "param_model__min_samples_split",
        "param_model__min_samples_leaf",
        "param_model__max_features",
        "param_model__max_samples",
        "param_model__bootstrap",
        "param_model__min_impurity_decrease",
        "param_model__class_weight",
    ],
    view_count=15,
)
# Out:
#     param_model__n_estimators  param_model__max_depth  \
# 17                        210                       7
# 70                        160                       7
# 62                         80                       9
# 23                        230                      11
# 65                        110                       9
# 5                         220                       5
# 68                        210                      11
# 77                         50                       5
# 72                        260                      11
# 31                        130                      19
# 14                        170                      17
# 22                        220                      11
# 75                        190                       9
# 53                        280                      13
# 29                        210                       9
#
#     param_model__max_leaf_nodes param_model__criterion  \
# 17                          240                   gini
# 70                         1620                entropy
# 62                         1290                   gini
# 23                         1190                entropy
# 65                         1470                entropy
# 5                          1640                entropy
# 68                         1700                   gini
# 77                          690                   gini
# 72                         1910                   gini
# 31                          170                   gini
# 14                         1650                entropy
# 22                          420                   gini
# 75                          460                   gini
# 53                         1640                   gini
# 29                          660                   gini
#
#     param_model__min_samples_split  param_model__min_samples_leaf  \
# 17                              18                              1
# 70                              19                              9
# 62                              12                              8
# 23                              15                              3
# 65                               3                              2
# 5                                7                              3
# 68                               8                              6
# 77                              11                              4
# 72                              17                              9
# 31                              12                              2
# 14                              17                              5
# 22                              10                              9
# 75                               3                              3
# 53                              12                              7
# 29                               6                              2
#
#    param_model__max_features param_model__max_samples  param_model__bootstrap  \
# 17                      sqrt                     None                    True
# 70                      log2                     None                    True
# 62                      log2                     None                   False
# 23                      log2                      0.6                    True
# 65                      log2                     None                   False
# 5                        0.5                      0.6                    True
# 68                      log2                      0.6                    True
# 77                       0.5                     None                    True
# 72                      log2                      0.6                    True
# 31                      sqrt                     None                   False
# 14                      sqrt                      0.6                    True
# 22                      sqrt                      0.6                    True
# 75                      sqrt                     None                    True
# 53                       0.5                      0.6                    True
# 29                      log2                     None                    True
#
#     param_model__min_impurity_decrease param_model__class_weight  \
# 17                                 0.0                  balanced
# 70                                 0.0          {0.0: 1, 1.0: 5}
# 62                                 0.0        balanced_subsample
# 23                                 0.0                  balanced
# 65                                 0.0        balanced_subsample
# 5                                  0.0        balanced_subsample
# 68                                 0.0          {0.0: 1, 1.0: 5}
# 77                                 0.0                  balanced
# 72                                 0.0                  balanced
# 31                                 0.0          {0.0: 5, 1.0: 1}
# 14                                 0.0          {0.0: 1, 1.0: 5}
# 22                                 0.0          {0.0: 1, 1.0: 5}
# 75                                 0.0          {0.0: 5, 1.0: 1}
# 53                                 0.0          {0.0: 5, 1.0: 1}
# 29                                 0.0          {0.0: 5, 1.0: 1}
#
#     mean_test_score  std_test_score  rank_test_score
# 17         0.930759        0.000637                1
# 70         0.930706        0.000529                2
# 62         0.930568        0.000915                3
# 23         0.930309        0.000783                4
# 65         0.930214        0.000338                5
# 5          0.930049        0.000947                6
# 68         0.929849        0.000461                7
# 77         0.929651        0.001070                8
# 72         0.929554        0.000743                9
# 31         0.929496        0.000652               10
# 14         0.929440        0.000213               11
# 22         0.929296        0.000461               12
# 75         0.929154        0.001318               13
# 53         0.929111        0.001009               14
# 29         0.929096        0.000978               15

# %%
# save best random forest classifier
best_pipeline_rf_rs = random_search_rf_hyper_tun.best_estimator_
best_pipeline_rf_rs
# Out:
# Pipeline(steps=[('drop_cols', ColumnDropper(columns=[])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin', NumericBinner(mapping={})),
#                 ('cat_flags',
#                  CategoricalBinaryFlagTransformer(flag_config={'Geography': [{'drop_original': True,
#                                                                               'flag_name': 'IsGermany',
#                                                                               'value': 'Germany'},
#                                                                              {'drop_original': True,
#                                                                               'flag_name': 'IsSpain',
#                                                                               'value': 'Spain'}...
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x124649370>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x1308806e0>)])),
#                 ('model',
#                  RandomForestClassifier(class_weight='balanced', max_depth=7,
#                                         max_leaf_nodes=240,
#                                         min_samples_split=18, n_estimators=210,
#                                         n_jobs=-1, random_state=42))])

# %% [markdown]
# ### Hyperparams tuning - Optuna

# %% [markdown]
# #### Define Objective Function

# %%
import optuna
from sklearn.base import clone
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

def objective_rf(trial):
    pipeline = clone(pipeline_rf)

    # =========================
    # STRUCTURE SEARCH
    # =========================
    poly_degree = trial.suggest_int("poly_degree", 1, 2)
    encoder_drop = trial.suggest_categorical("encoder_drop", ["if_binary", None])

    cat_flags_idx = trial.suggest_int(
        "cat_flags_idx", 0, len(cat_flags_config_all_options) - 1
    )
    num_bin_idx = trial.suggest_int(
        "num_bin_idx", 0, len(num_bin_mapping_all_options) - 1
    )

    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[cat_flags_idx])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[num_bin_idx])

    drop_columns_options = [
        [],
        ["Tenure"],
        ["Tenure", "HasCrCard"],
    ]
    drop_columns = trial.suggest_categorical("drop_cols", drop_columns_options)

    # =========================
    # APPLY STRUCTURE
    # =========================
    pipeline.set_params(
        drop_cols__columns=drop_columns,
        preprocessing__num__poly_features__degree=poly_degree,
        preprocessing__cat__encoder__drop=encoder_drop,
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )


    # =========================
    # RANDOM FOREST HYPERPARAMETERS
    # =========================
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])

    # Suggest hyperparameters
    rf_params = {
        "n_estimators": trial.suggest_int("n_estimators", 10, 300, step=10),
        "max_depth": trial.suggest_int("max_depth", 3, 20, step=2),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 10, 2000, step=10),
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy"]),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", 0.5, 0.8]),
        "min_impurity_decrease": trial.suggest_categorical("min_impurity_decrease", [0.0, 0.1]),
        "class_weight": trial.suggest_categorical(
            "class_weight",
            [
                "balanced",
                "balanced_subsample",
                {0.0: 1, 1.0: 5},
                {0.0: 5, 1.0: 1},
            ],
        ),
        "bootstrap": bootstrap,
        "random_state": 42,
        "n_jobs": -1,
    }

    # Only suggest max_samples if bootstrap=True
    if bootstrap:
        rf_params["max_samples"] = trial.suggest_categorical(
            "max_samples",
            [None, 0.9, 0.6, 0.3], # add more options than in RandomizedSearchCV
        )

    pipeline.set_params(model=RandomForestClassifier(**rf_params))

    # =========================
    # CROSS-VALIDATION
    # =========================
    scores = cross_val_score(
        pipeline,
        X_raw,
        y_raw,
        cv=skf,
        scoring="roc_auc",
        n_jobs=-1,
    )

    return scores.mean()

# %% [markdown]
# #### Run Study

# %%
# %%time

study_rf = optuna.create_study(direction="maximize")
study_rf.optimize(objective_rf, n_trials=50, show_progress_bar=False)
# Out:
# CPU times: user 547 ms, sys: 190 ms, total: 736 ms
# Wall time: 42.2 s

# %% [markdown]
# #### Inspect Results

# %%
print("Best ROC AUC:", study_rf.best_value)
print("Best params:", study_rf.best_params)
# Out:
# Best ROC AUC: 0.9325322419315945
# Best params: {'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 2, 'num_bin_idx': 1, 'drop_cols': [], 'bootstrap': True, 'n_estimators': 150, 'max_depth': 7, 'max_leaf_nodes': 1380, 'criterion': 'entropy', 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 'log2', 'min_impurity_decrease': 0.0, 'class_weight': 'balanced_subsample', 'max_samples': None}

# %% [markdown]
# #### Best Model Pipeline

# %%
import copy
from sklearn.base import clone
from sklearn.ensemble import RandomForestClassifier

def build_best_rf_pipeline(study):
    """
    Build a final RandomForest pipeline based on best Optuna parameters.
    """
    best = study.best_params
    pipeline = clone(pipeline_rf)

    # ===== STRUCTURE =====
    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[best["cat_flags_idx"]])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[best["num_bin_idx"]])

    pipeline.set_params(
        drop_cols__columns=best["drop_cols"],
        preprocessing__num__poly_features__degree=best["poly_degree"],
        preprocessing__cat__encoder__drop=best["encoder_drop"],
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    # ===== RANDOM FOREST HYPERPARAMETERS =====
    rf_params = {
        "n_estimators": best["n_estimators"],
        "max_depth": best["max_depth"],
        "max_leaf_nodes": best["max_leaf_nodes"],
        "criterion": best["criterion"],
        "min_samples_split": best["min_samples_split"],
        "min_samples_leaf": best["min_samples_leaf"],
        "max_features": best["max_features"],
        "min_impurity_decrease": best["min_impurity_decrease"],
        "class_weight": best["class_weight"],
        "bootstrap": best["bootstrap"],
        "random_state": 42,
        "n_jobs": -1,
    }

    # Only include max_samples if bootstrap=True
    if best.get("bootstrap", True) and "max_samples" in best:
        rf_params["max_samples"] = best["max_samples"]

    pipeline.set_params(model=RandomForestClassifier(**rf_params))

    return pipeline

# %%
best_pipeline_rf_opt = build_best_rf_pipeline(study_rf)

best_pipeline_rf_opt.fit(X_raw, y_raw)
# Out:
# Pipeline(steps=[('drop_cols', ColumnDropper(columns=[])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin',
#                  NumericBinner(mapping={'CreditScore': {'bins': [0, 675, inf],
#                                                         'drop_original': True,
#                                                         'labels': ['low',
#                                                                    'high'],
#                                                         'new_col': 'CreditScoreScore'},
#                                         'EstimatedSalary': {'bins': [0, 25000,
#                                                                      100000,
#                                                                      inf],
#                                                             'drop_original': True,
#                                                             'labels': ['low',
#                                                                        'medium'...
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x133357c80>)])),
#                 ('model',
#                  RandomForestClassifier(class_weight='balanced_subsample',
#                                         criterion='entropy', max_depth=7,
#                                         max_features='log2',
#                                         max_leaf_nodes=1380, min_samples_leaf=5,
#                                         min_samples_split=19, n_estimators=150,
#                                         n_jobs=-1, random_state=42))])

# %% [markdown]
# #### Visualization

# %%
# use matplotlib.pyplot to be shown on github
# optuna.visualization.plot_optimization_history(study_rf) - can be used as alternative that relies on plotly
import optuna.visualization.matplotlib as vis_mpl
import matplotlib.pyplot as plt

fig = vis_mpl.plot_optimization_history(study_rf)
plt.show()

# %%
fig = vis_mpl.plot_param_importances(study_rf)
plt.show()

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.base import clone
from sklearn.model_selection import cross_val_score
import copy
import optuna

# %% [markdown]
# ### Define Optuna Objective

# %%
def objective_gb(trial):
    pipeline = clone(pipeline_rf)

    # =========================
    # STRUCTURE SEARCH
    # =========================
    poly_degree = trial.suggest_int("poly_degree", 1, 3)
    encoder_drop = trial.suggest_categorical("encoder_drop", ["if_binary", None])

    cat_flags_idx = trial.suggest_int(
        "cat_flags_idx", 0, len(cat_flags_config_all_options)-1
    )
    num_bin_idx = trial.suggest_int(
        "num_bin_idx", 0, len(num_bin_mapping_all_options)-1
    )

    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[cat_flags_idx])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[num_bin_idx])

    # =========================
    # DROP COLUMNS
    # =========================
    drop_columns_options = [
        [],
        ["Tenure"],
        ["Tenure", "HasCrCard"],
    ]
    drop_columns = trial.suggest_categorical("drop_cols", drop_columns_options)

    # prune invalid drop columns
    protected_columns = set(num_bin_mapping.keys())
    if any(col in protected_columns for col in drop_columns):
        raise optuna.exceptions.TrialPruned()

    pipeline.set_params(
        drop_cols__columns=drop_columns,
        preprocessing__num__poly_features__degree=poly_degree,
        preprocessing__cat__encoder__drop=encoder_drop,
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    # =========================
    # GRADIENT BOOSTING HYPERPARAMETERS
    # =========================
    gb_params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 400, step=25),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 1.0, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", 0.5, 0.8]),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "random_state": 42,
    }

    pipeline.set_params(model=GradientBoostingClassifier(**gb_params))

    # =========================
    # CROSS-VALIDATION
    # =========================
    scores = cross_val_score(
        pipeline,
        X_raw,
        y_raw,
        cv=skf,
        scoring="roc_auc",
        n_jobs=-1,
    )

    return scores.mean()

# %% [markdown]
# ### Run Study

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)  # suppress logs
study_gb = optuna.create_study(direction="maximize")
study_gb.optimize(objective_gb, n_trials=100, show_progress_bar=False)

# %%
print("Best ROC AUC:", study_gb.best_value)
print("Best params:", study_gb.best_params)
# Out:
# Best ROC AUC: 0.9366290022529316
# Best params: {'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 3, 'num_bin_idx': 2, 'drop_cols': [], 'n_estimators': 325, 'learning_rate': 0.0243362293271378, 'max_depth': 3, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_features': 0.5, 'subsample': 0.7629548749013689}

# %% [markdown]
# ### Best Model Pipeline

# %%
def build_best_gb_pipeline(study):
    best = study.best_params
    pipeline = clone(pipeline_rf)

    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[best["cat_flags_idx"]])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[best["num_bin_idx"]])

    pipeline.set_params(
        drop_cols__columns=best["drop_cols"],
        preprocessing__num__poly_features__degree=best["poly_degree"],
        preprocessing__cat__encoder__drop=best["encoder_drop"],
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    gb_params = {
        "n_estimators": best["n_estimators"],
        "learning_rate": best["learning_rate"],
        "max_depth": best["max_depth"],
        "min_samples_split": best["min_samples_split"],
        "min_samples_leaf": best["min_samples_leaf"],
        "max_features": best["max_features"],
        "subsample": best["subsample"],
        "random_state": 42,
    }

    pipeline.set_params(model=GradientBoostingClassifier(**gb_params))
    return pipeline

# %%
best_pipeline_gb_opt = build_best_gb_pipeline(study_gb)
best_pipeline_gb_opt.fit(X_raw, y_raw)
# Out:
# Pipeline(steps=[('drop_cols', ColumnDropper(columns=[])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin',
#                  NumericBinner(mapping={'EstimatedSalary': {'bins': [0, 25000,
#                                                                      100000,
#                                                                      inf],
#                                                             'drop_original': True,
#                                                             'labels': ['low',
#                                                                        'medium',
#                                                                        'high'],
#                                                             'new_col': 'SalaryScore'}})),
#                 ('cat_flags',
#                  CategoricalBinaryFlagTransformer(flag_config={'Geography': [...
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x133531790>)])),
#                 ('model',
#                  GradientBoostingClassifier(learning_rate=0.0243362293271378,
#                                             max_features=0.5,
#                                             min_samples_leaf=10,
#                                             min_samples_split=14,
#                                             n_estimators=325, random_state=42,
#                                             subsample=0.7629548749013689))])

# %% [markdown]
# ### Visualizations

# %%
fig = vis_mpl.plot_optimization_history(study_gb)
plt.show()

# %%
fig = vis_mpl.plot_param_importances(study_gb)
plt.show()

# %% [markdown]
# ## Adaboost

# %% [markdown]
# ### Optuna Objective for AdaBoost

# %%
import optuna
import copy
from sklearn.base import clone
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score


def objective_adaboost(trial):
    pipeline = clone(pipeline_rf)

    # =========================
    # STRUCTURE SEARCH
    # =========================

    drop_columns = trial.suggest_categorical(
        "drop_cols",
        [
            [],
            ["Tenure"],
            ["Tenure", "HasCrCard"],
        ],
    )

    poly_degree = trial.suggest_int("poly_degree", 1, 3)

    encoder_drop = trial.suggest_categorical(
        "encoder_drop",
        ["if_binary", None],
    )

    cat_flags_idx = trial.suggest_int(
        "cat_flags_idx",
        0,
        len(cat_flags_config_all_options) - 1,
    )

    num_bin_idx = trial.suggest_int(
        "num_bin_idx",
        0,
        len(num_bin_mapping_all_options) - 1,
    )

    pipeline.set_params(
        drop_cols__columns=drop_columns,
        preprocessing__num__poly_features__degree=poly_degree,
        preprocessing__cat__encoder__drop=encoder_drop,
        cat_flags__flag_config=copy.deepcopy(
            cat_flags_config_all_options[cat_flags_idx]
        ),
        num_bin__mapping=copy.deepcopy(
            num_bin_mapping_all_options[num_bin_idx]
        ),
    )

    # =========================
    # ADABOOST HYPERPARAMETERS
    # =========================

    # Base tree complexity
    tree_max_depth = trial.suggest_int("tree_max_depth", 1, 5)

    base_estimator = DecisionTreeClassifier(
        max_depth=tree_max_depth,
        min_samples_split=trial.suggest_int("tree_min_samples_split", 2, 20),
        min_samples_leaf=trial.suggest_int("tree_min_samples_leaf", 1, 10),
        random_state=42,
    )

    ada_params = {
        "estimator": base_estimator,
        "n_estimators": trial.suggest_int("n_estimators", 50, 400, step=25),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 1.0, log=True),
        "random_state": 42,
    }

    pipeline.set_params(model=AdaBoostClassifier(**ada_params))

    scores = cross_val_score(
        pipeline,
        X_raw,
        y_raw,
        cv=skf,
        scoring="roc_auc",
        n_jobs=-1,
    )

    return scores.mean()

# %% [markdown]
# ### Run Study

# %%
# %%time

study_ada = optuna.create_study(direction="maximize")
study_ada.optimize(objective_adaboost, n_trials=30)
# Out:
# [I 2026-03-03 14:03:23,930] A new study created in memory with name: no-name-f3630120-720e-43ca-a426-26e639dafc13
# [I 2026-03-03 14:03:26,478] Trial 0 finished with value: 0.9305418729369791 and parameters: {'drop_cols': ['Tenure', 'HasCrCard'], 'poly_degree': 1, 'encoder_drop': None, 'cat_flags_idx': 2, 'num_bin_idx': 3, 'tree_max_depth': 3, 'tree_min_samples_split': 4, 'tree_min_samples_leaf': 1, 'n_estimators': 175, 'learning_rate': 0.020958719586349622}. Best is trial 0 with value: 0.9305418729369791.
# [I 2026-03-03 14:03:28,414] Trial 1 finished with value: 0.9269272892270215 and parameters: {'drop_cols': [], 'poly_degree': 1, 'encoder_drop': None, 'cat_flags_idx': 4, 'num_bin_idx': 1, 'tree_max_depth': 5, 'tree_min_samples_split': 20, 'tree_min_samples_leaf': 7, 'n_estimators': 125, 'learning_rate': 0.5815684194034022}. Best is trial 0 with value: 0.9305418729369791.
# [I 2026-03-03 14:04:00,685] Trial 2 finished with value: 0.9310216171493629 and parameters: {'drop_cols': [], 'poly_degree': 3, 'encoder_drop': None, 'cat_flags_idx': 0, 'num_bin_idx': 2, 'tree_max_depth': 3, 'tree_min_samples_split': 10, 'tree_min_samples_leaf': 8, 'n_estimators': 275, 'learning_rate': 0.014440859504570467}. Best is trial 2 with value: 0.9310216171493629.
# [I 2026-03-03 14:05:47,074] Trial 3 finished with value: 0.9212388814882214 and parameters: {'drop_cols': [], 'poly_degree': 3, 'encoder_drop': None, 'cat_flags_idx': 1, 'num_bin_idx': 0, 'tree_max_depth': 3, 'tree_min_samples_split': 2, 'tree_min_samples_leaf': 1, 'n_estimators': 375, 'learning_rate': 0.8425628447865611}. Best is trial 2 with value: 0.9310216171493629.
# [I 2026-03-03 14:05:48,976] Trial 4 finished with value: 0.9193490528383034 and parameters: {'drop_cols': ['Tenure', 'HasCrCard'], 'poly_degree': 1, 'encoder_drop': None, 'cat_flags_idx': 1, 'num_bin_idx': 3, 'tree_max_depth': 1, 'tree_min_samples_split': 13, 'tree_min_samples_leaf': 4, 'n_estimators': 250, 'learning_rate': 0.0686130608438104}. Best is trial 2 with value: 0.9310216171493629.
# [I 2026-03-03 14:06:07,526] Trial 5 finished with value: 0.9357691260004236 and parameters: {'drop_cols': [], 'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 4, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 14, 'tree_min_samples_leaf': 3, 'n_estimators': 400, 'learning_rate': 0.10009971169885913}. Best is trial 5 with value: 0.9357691260004236.
# [I 2026-03-03 14:06:08,422] Trial 6 finished with value: 0.9322020407907886 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 1, 'encoder_drop': 'if_binary', 'cat_flags_idx': 1, 'num_bin_idx': 1, 'tree_max_depth': 4, 'tree_min_samples_split': 13, 'tree_min_samples_leaf': 2, 'n_estimators': 150, 'learning_rate': 0.4678522027001469}. Best is trial 5 with value: 0.9357691260004236.
# [I 2026-03-03 14:06:21,600] Trial 7 finished with value: 0.9324419076614747 and parameters: {'drop_cols': ['Tenure', 'HasCrCard'], 'poly_degree': 3, 'encoder_drop': 'if_binary', 'cat_flags_idx': 1, 'num_bin_idx': 1, 'tree_max_depth': 5, 'tree_min_samples_split': 17, 'tree_min_samples_leaf': 6, 'n_estimators': 250, 'learning_rate': 0.041226030641190646}. Best is trial 5 with value: 0.9357691260004236.
# [I 2026-03-03 14:06:53,641] Trial 8 finished with value: 0.9339034137171698 and parameters: {'drop_cols': [], 'poly_degree': 3, 'encoder_drop': None, 'cat_flags_idx': 4, 'num_bin_idx': 2, 'tree_max_depth': 2, 'tree_min_samples_split': 11, 'tree_min_samples_leaf': 2, 'n_estimators': 175, 'learning_rate': 0.2561617410252925}. Best is trial 5 with value: 0.9357691260004236.
# [I 2026-03-03 14:06:57,289] Trial 9 finished with value: 0.9257457421658911 and parameters: {'drop_cols': ['Tenure', 'HasCrCard'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 2, 'num_bin_idx': 2, 'tree_max_depth': 1, 'tree_min_samples_split': 13, 'tree_min_samples_leaf': 6, 'n_estimators': 350, 'learning_rate': 0.017974820386311395}. Best is trial 5 with value: 0.9357691260004236.
# [I 2026-03-03 14:07:11,313] Trial 10 finished with value: 0.9359984979825331 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 7, 'tree_min_samples_leaf': 4, 'n_estimators': 400, 'learning_rate': 0.154391447204384}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:07:25,578] Trial 11 finished with value: 0.9359771756923125 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 7, 'tree_min_samples_leaf': 4, 'n_estimators': 400, 'learning_rate': 0.14922067701543304}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:07:37,192] Trial 12 finished with value: 0.9356684992865819 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 7, 'tree_min_samples_leaf': 5, 'n_estimators': 325, 'learning_rate': 0.19122865213991685}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:07:39,873] Trial 13 finished with value: 0.9348258622995648 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 6, 'tree_min_samples_leaf': 4, 'n_estimators': 75, 'learning_rate': 0.16603947779097414}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:07:47,384] Trial 14 finished with value: 0.9316665016574407 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 0, 'tree_max_depth': 1, 'tree_min_samples_split': 8, 'tree_min_samples_leaf': 9, 'n_estimators': 325, 'learning_rate': 0.0821015782409863}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:07:56,983] Trial 15 finished with value: 0.9313687858449015 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 1, 'tree_max_depth': 4, 'tree_min_samples_split': 5, 'tree_min_samples_leaf': 4, 'n_estimators': 400, 'learning_rate': 0.3530643264532907}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:08:07,854] Trial 16 finished with value: 0.9348083593017372 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 2, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 9, 'tree_min_samples_leaf': 10, 'n_estimators': 300, 'learning_rate': 0.04300286458615731}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:08:38,670] Trial 17 finished with value: 0.9323429475289619 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 3, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 1, 'tree_max_depth': 4, 'tree_min_samples_split': 2, 'tree_min_samples_leaf': 5, 'n_estimators': 350, 'learning_rate': 0.14129102843327834}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:08:47,397] Trial 18 finished with value: 0.930734954814755 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 4, 'num_bin_idx': 0, 'tree_max_depth': 1, 'tree_min_samples_split': 4, 'tree_min_samples_leaf': 3, 'n_estimators': 400, 'learning_rate': 0.052858004994601866}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:08:48,285] Trial 19 finished with value: 0.9321785111473241 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 1, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 1, 'tree_max_depth': 2, 'tree_min_samples_split': 8, 'tree_min_samples_leaf': 7, 'n_estimators': 225, 'learning_rate': 0.28115400319299305}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:08:50,784] Trial 20 finished with value: 0.918222640834098 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 2, 'num_bin_idx': 0, 'tree_max_depth': 3, 'tree_min_samples_split': 11, 'tree_min_samples_leaf': 3, 'n_estimators': 50, 'learning_rate': 0.027832460462961665}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:09:10,095] Trial 21 finished with value: 0.9356966700609779 and parameters: {'drop_cols': [], 'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 4, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 16, 'tree_min_samples_leaf': 3, 'n_estimators': 400, 'learning_rate': 0.11934848717503639}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:09:27,209] Trial 22 finished with value: 0.9357057457500803 and parameters: {'drop_cols': [], 'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 4, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 15, 'tree_min_samples_leaf': 4, 'n_estimators': 350, 'learning_rate': 0.11372799651487493}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:09:37,071] Trial 23 finished with value: 0.9320410937575067 and parameters: {'drop_cols': [], 'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 4, 'num_bin_idx': 0, 'tree_max_depth': 1, 'tree_min_samples_split': 19, 'tree_min_samples_leaf': 2, 'n_estimators': 375, 'learning_rate': 0.08519618812263467}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:09:42,050] Trial 24 finished with value: 0.9355723624522914 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 1, 'tree_max_depth': 2, 'tree_min_samples_split': 6, 'tree_min_samples_leaf': 5, 'n_estimators': 375, 'learning_rate': 0.20395860375601757}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:09:44,727] Trial 25 finished with value: 0.9346699268018028 and parameters: {'drop_cols': [], 'poly_degree': 1, 'encoder_drop': 'if_binary', 'cat_flags_idx': 4, 'num_bin_idx': 0, 'tree_max_depth': 3, 'tree_min_samples_split': 14, 'tree_min_samples_leaf': 4, 'n_estimators': 325, 'learning_rate': 0.061987194276424816}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:10:04,080] Trial 26 finished with value: 0.9353004049270259 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 3, 'encoder_drop': None, 'cat_flags_idx': 3, 'num_bin_idx': 1, 'tree_max_depth': 2, 'tree_min_samples_split': 10, 'tree_min_samples_leaf': 3, 'n_estimators': 400, 'learning_rate': 0.13890533467663413}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:10:19,410] Trial 27 finished with value: 0.9351388843309655 and parameters: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 2, 'num_bin_idx': 0, 'tree_max_depth': 3, 'tree_min_samples_split': 17, 'tree_min_samples_leaf': 6, 'n_estimators': 300, 'learning_rate': 0.1063639463007077}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:10:23,592] Trial 28 finished with value: 0.935386733602984 and parameters: {'drop_cols': ['Tenure', 'HasCrCard'], 'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 3, 'num_bin_idx': 2, 'tree_max_depth': 1, 'tree_min_samples_split': 12, 'tree_min_samples_leaf': 2, 'n_estimators': 375, 'learning_rate': 0.35350732762515213}. Best is trial 10 with value: 0.9359984979825331.
# [I 2026-03-03 14:10:25,193] Trial 29 finished with value: 0.9330925257439621 and parameters: {'drop_cols': [], 'poly_degree': 1, 'encoder_drop': None, 'cat_flags_idx': 4, 'num_bin_idx': 3, 'tree_max_depth': 3, 'tree_min_samples_split': 8, 'tree_min_samples_leaf': 5, 'n_estimators': 200, 'learning_rate': 0.032596779216845034}. Best is trial 10 with value: 0.9359984979825331.
# CPU times: user 620 ms, sys: 612 ms, total: 1.23 s
# Wall time: 7min 1s

# %%
print("Best ROC AUC:", study_ada.best_value)
print("Best params:", study_ada.best_params)
# Out:
# Best ROC AUC: 0.9359984979825331
# Best params: {'drop_cols': ['Tenure'], 'poly_degree': 2, 'encoder_drop': 'if_binary', 'cat_flags_idx': 3, 'num_bin_idx': 0, 'tree_max_depth': 2, 'tree_min_samples_split': 7, 'tree_min_samples_leaf': 4, 'n_estimators': 400, 'learning_rate': 0.154391447204384}

# %% [markdown]
# ### Best Model Pipeline

# %%
def build_best_adaboost_pipeline(study):
    best = study.best_params

    pipeline = clone(pipeline_rf)

    # =========================
    # STRUCTURE
    # =========================

    cat_flags_config = copy.deepcopy(
        cat_flags_config_all_options[best["cat_flags_idx"]]
    )

    num_bin_mapping = copy.deepcopy(
        num_bin_mapping_all_options[best["num_bin_idx"]]
    )

    pipeline.set_params(
        drop_cols__columns=best["drop_cols"],
        preprocessing__num__poly_features__degree=best["poly_degree"],
        preprocessing__cat__encoder__drop=best["encoder_drop"],
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    # =========================
    # MODEL
    # =========================

    base_estimator = DecisionTreeClassifier(
        max_depth=best["tree_max_depth"],
        min_samples_split=best["tree_min_samples_split"],
        min_samples_leaf=best["tree_min_samples_leaf"],
        random_state=42,
    )

    model = AdaBoostClassifier(
        estimator=base_estimator,
        n_estimators=best["n_estimators"],
        learning_rate=best["learning_rate"],
        random_state=42,
    )

    pipeline.set_params(model=model)

    return pipeline

# %%
best_pipeline_ada_opt = build_best_adaboost_pipeline(study_ada)
best_pipeline_ada_opt.fit(X_raw, y_raw)
# Out:
# Pipeline(steps=[('drop_cols', ColumnDropper(columns=['Tenure'])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin', NumericBinner(mapping={})),
#                 ('cat_flags',
#                  CategoricalBinaryFlagTransformer(flag_config={'Geography': [{'drop_original': True,
#                                                                               'flag_name': 'IsGermany',
#                                                                               'value': 'Germany'},
#                                                                              {'drop_original': True,
#                                                                               'flag_name': 'IsSpain',
#                                                                               'value':...
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x130dcd820>)])),
#                 ('model',
#                  AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=2,
#                                                                      min_samples_leaf=4,
#                                                                      min_samples_split=7,
#                                                                      random_state=42),
#                                     learning_rate=0.154391447204384,
#                                     n_estimators=400, random_state=42))])

# %% [markdown]
# ### Visualizations

# %%
fig = vis_mpl.plot_optimization_history(study_ada)
plt.show()

# %%
# optuna.visualization.plot_param_importances(study_ada)
fig = vis_mpl.plot_param_importances(study_ada)
plt.show()

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb
from sklearn.base import clone
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Define Objective

# %%
def objective_xgb(trial):
    pipeline = clone(pipeline_rf)

    # =========================
    # STRUCTURE SEARCH
    # =========================
    poly_degree = trial.suggest_int("poly_degree", 1, 3)

    encoder_drop = trial.suggest_categorical("encoder_drop", ["if_binary", None])

    cat_flags_idx = trial.suggest_int(
        "cat_flags_idx", 0, len(cat_flags_config_all_options) - 1
    )

    num_bin_idx = trial.suggest_int(
        "num_bin_idx", 0, len(num_bin_mapping_all_options) - 1
    )

    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[cat_flags_idx])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[num_bin_idx])

    # =========================
    # SMART DROP LOGIC
    # =========================
    protected_columns = set(num_bin_mapping.keys())

    ALL_DROP_OPTIONS = [
        [],
        ["Tenure"],
        ["Tenure", "HasCrCard"],
        ["Tenure", "HasCrCard", "EstimatedSalary"],
        ["Tenure", "HasCrCard", "CreditScore"],
        ["Tenure", "HasCrCard", "EstimatedSalary", "CreditScore"],
    ]

    drop_columns = trial.suggest_categorical("drop_cols", ALL_DROP_OPTIONS)

    # Prune if drop_columns conflicts with protected_columns
    if any(col in protected_columns for col in drop_columns):
        raise optuna.exceptions.TrialPruned()

    # =========================
    # APPLY STRUCTURE
    # =========================
    pipeline.set_params(
        drop_cols__columns=drop_columns,
        preprocessing__num__poly_features__degree=poly_degree,
        preprocessing__cat__encoder__drop=encoder_drop,
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    # =========================
    # XGBOOST HYPERPARAMETERS
    # =========================
    xgb_params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 400, step=25),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 5.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 5.0),
        "random_state": 42,
        "use_label_encoder": False,
        "eval_metric": "auc",
        "n_jobs": -1,
    }

    pipeline.set_params(model=xgb.XGBClassifier(**xgb_params))

    # =========================
    # CROSS-VALIDATION
    # =========================
    scores = cross_val_score(
        pipeline,
        X_raw,
        y_raw,
        cv=skf,
        scoring="roc_auc",
        n_jobs=-1,
    )

    return scores.mean()

# %% [markdown]
# ### Run Study

# %%
# %%time

# suppress Optuna info logs
optuna.logging.set_verbosity(optuna.logging.WARNING)

study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(objective_xgb, n_trials=200)
# Out:
# CPU times: user 2.07 s, sys: 463 ms, total: 2.53 s
# Wall time: 22.8 s

# %%
print("Best ROC AUC:", study_xgb.best_value)
print("Best params:", study_xgb.best_params)
# Out:
# Best ROC AUC: 0.9369650483120333
# Best params: {'poly_degree': 1, 'encoder_drop': None, 'cat_flags_idx': 1, 'num_bin_idx': 1, 'drop_cols': ['Tenure'], 'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.22545878046149048, 'subsample': 0.8100024200131671, 'colsample_bytree': 0.7373211078599748, 'gamma': 1.5327583557683286, 'reg_alpha': 4.946882393540392, 'reg_lambda': 4.11613448594875}

# %% [markdown]
# ### Best Model Pipeline

# %%
def build_best_xgb_pipeline(study):
    best = study.best_params
    pipeline = clone(pipeline_rf)

    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[best["cat_flags_idx"]])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[best["num_bin_idx"]])

    pipeline.set_params(
        drop_cols__columns=best["drop_cols"],
        preprocessing__num__poly_features__degree=best["poly_degree"],
        preprocessing__cat__encoder__drop=best["encoder_drop"],
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    xgb_params = {
        "n_estimators": best["n_estimators"],
        "max_depth": best["max_depth"],
        "learning_rate": best["learning_rate"],
        "subsample": best["subsample"],
        "colsample_bytree": best["colsample_bytree"],
        "gamma": best["gamma"],
        "reg_alpha": best["reg_alpha"],
        "reg_lambda": best["reg_lambda"],
        "random_state": 42,
        "use_label_encoder": False,
        "eval_metric": "auc",
        "n_jobs": -1,
    }

    pipeline.set_params(model=xgb.XGBClassifier(**xgb_params))
    return pipeline

best_pipeline_xgb_opt = build_best_xgb_pipeline(study_xgb)
best_pipeline_xgb_opt.fit(X_raw, y_raw)
# Out:
# Pipeline(steps=[('drop_cols', ColumnDropper(columns=['Tenure'])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin',
#                  NumericBinner(mapping={'CreditScore': {'bins': [0, 675, inf],
#                                                         'drop_original': True,
#                                                         'labels': ['low',
#                                                                    'high'],
#                                                         'new_col': 'CreditScoreScore'},
#                                         'EstimatedSalary': {'bins': [0, 25000,
#                                                                      100000,
#                                                                      inf],
#                                                             'drop_original': True,
#                                                             'labels': ['low',...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.22545878046149048, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=3,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=300, n_jobs=-1,
#                                num_parallel_tree=None, random_state=42, ...))])

# %% [markdown]
# ### Visualizations

# %%
# optuna.visualization.plot_optimization_history(study_xgb)
fig = vis_mpl.plot_optimization_history(study_xgb)
plt.show()

# %%
# optuna.visualization.plot_param_importances(study_xgb)
fig = vis_mpl.plot_param_importances(study_xgb)
plt.show()

# %% [markdown]
# ## LightGBM

# %%
import lightgbm as lgb
from sklearn.base import clone
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Define LightGBM Objective

# %%
def objective_lgb(trial):
    pipeline = clone(pipeline_rf)

    # =========================
    # STRUCTURE SEARCH
    # =========================
    poly_degree = trial.suggest_int("poly_degree", 1, 3)
    encoder_drop = trial.suggest_categorical("encoder_drop", ["if_binary", None])

    cat_flags_idx = trial.suggest_int(
        "cat_flags_idx", 0, len(cat_flags_config_all_options) - 1
    )

    num_bin_idx = trial.suggest_int(
        "num_bin_idx", 0, len(num_bin_mapping_all_options) - 1
    )

    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[cat_flags_idx])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[num_bin_idx])

    # =========================
    # SMART DROP LOGIC
    # =========================
    protected_columns = set(num_bin_mapping.keys())

    ALL_DROP_OPTIONS = [
        [],
        ["Tenure"],
        ["Tenure", "HasCrCard"],
        ["Tenure", "HasCrCard", "EstimatedSalary"],
        ["Tenure", "HasCrCard", "CreditScore"],
        ["Tenure", "HasCrCard", "EstimatedSalary", "CreditScore"],
    ]

    drop_columns = trial.suggest_categorical("drop_cols", ALL_DROP_OPTIONS)

    # Prune invalid configs
    if any(col in protected_columns for col in drop_columns):
        raise optuna.exceptions.TrialPruned()

    # =========================
    # APPLY STRUCTURE
    # =========================
    pipeline.set_params(
        drop_cols__columns=drop_columns,
        preprocessing__num__poly_features__degree=poly_degree,
        preprocessing__cat__encoder__drop=encoder_drop,
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    # =========================
    # LIGHTGBM HYPERPARAMETERS
    # =========================
    lgb_params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 400, step=25),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 20, 150),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 50),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 5.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 5.0),
        "random_state": 42,
        "n_jobs": -1,
        "verbosity": -1,
    }

    pipeline.set_params(model=lgb.LGBMClassifier(**lgb_params))

    # =========================
    # CROSS-VALIDATION
    # =========================
    scores = cross_val_score(
        pipeline,
        X_raw,
        y_raw,
        cv=skf,
        scoring="roc_auc",
        n_jobs=-1,
    )

    return scores.mean()

# %% [markdown]
# ### Run LightGBM Study

# %%
# %%time

optuna.logging.set_verbosity(optuna.logging.WARNING)  # suppress logs
study_lgb = optuna.create_study(direction="maximize")
study_lgb.optimize(objective_lgb, n_trials=200, show_progress_bar=False)
# Out:
# CPU times: user 2.59 s, sys: 975 ms, total: 3.56 s
# Wall time: 3min 36s

# %%
print("Best ROC AUC:", study_lgb.best_value)
print("Best params:", study_lgb.best_params)
# Out:
# Best ROC AUC: 0.9368236257510172
# Best params: {'poly_degree': 2, 'encoder_drop': None, 'cat_flags_idx': 1, 'num_bin_idx': 0, 'drop_cols': ['Tenure', 'HasCrCard', 'EstimatedSalary'], 'n_estimators': 375, 'max_depth': 3, 'learning_rate': 0.025030463251219333, 'num_leaves': 28, 'min_child_samples': 13, 'subsample': 0.5259828008944356, 'colsample_bytree': 0.7846454348813654, 'reg_alpha': 0.8285531440517132, 'reg_lambda': 4.648815918238638}

# %% [markdown]
# ### Best Model Pipeline

# %%
def build_best_lgb_pipeline(study):
    best = study.best_params
    pipeline = clone(pipeline_rf)

    cat_flags_config = copy.deepcopy(cat_flags_config_all_options[best["cat_flags_idx"]])
    num_bin_mapping = copy.deepcopy(num_bin_mapping_all_options[best["num_bin_idx"]])

    pipeline.set_params(
        drop_cols__columns=best["drop_cols"],
        preprocessing__num__poly_features__degree=best["poly_degree"],
        preprocessing__cat__encoder__drop=best["encoder_drop"],
        cat_flags__flag_config=cat_flags_config,
        num_bin__mapping=num_bin_mapping,
    )

    lgb_params = {
        "n_estimators": best["n_estimators"],
        "max_depth": best["max_depth"],
        "learning_rate": best["learning_rate"],
        "num_leaves": best["num_leaves"],
        "min_child_samples": best["min_child_samples"],
        "subsample": best["subsample"],
        "colsample_bytree": best["colsample_bytree"],
        "reg_alpha": best["reg_alpha"],
        "reg_lambda": best["reg_lambda"],
        "random_state": 42,
        "n_jobs": -1,
        "verbosity": -1,
    }

    pipeline.set_params(model=lgb.LGBMClassifier(**lgb_params))
    return pipeline

best_pipeline_lgb_opt = build_best_lgb_pipeline(study_lgb)
best_pipeline_lgb_opt.fit(X_raw, y_raw)
# Out:
# Pipeline(steps=[('drop_cols',
#                  ColumnDropper(columns=['Tenure', 'HasCrCard',
#                                         'EstimatedSalary'])),
#                 ('num_flags', NumericBinaryFlagTransformer(flag_config={})),
#                 ('num_bin', NumericBinner(mapping={})),
#                 ('cat_flags',
#                  CategoricalBinaryFlagTransformer(flag_config={'Geography': [{'drop_original': True,
#                                                                               'flag_name': 'IsGermany',
#                                                                               'value': 'Germany'}]})),
#                 ('top_n', TopNCateg...
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x124754140>)])),
#                 ('model',
#                  LGBMClassifier(colsample_bytree=0.7846454348813654,
#                                 learning_rate=0.025030463251219333, max_depth=3,
#                                 min_child_samples=13, n_estimators=375,
#                                 n_jobs=-1, num_leaves=28, random_state=42,
#                                 reg_alpha=0.8285531440517132,
#                                 reg_lambda=4.648815918238638,
#                                 subsample=0.5259828008944356, verbosity=-1))])

# %% [markdown]
# ### Visualizations

# %%
# optuna.visualization.plot_optimization_history(study_lgb)
fig = vis_mpl.plot_optimization_history(study_lgb)
plt.show()

# %%
# optuna.visualization.plot_param_importances(study_lgb)
fig = vis_mpl.plot_param_importances(study_lgb)
plt.show()

# %% [markdown]
# ## Test Data Prediction

# %%
test_raw_df = pd.read_csv("downloads/test.csv")
test_raw_df.head()
# Out:
#       id  CustomerId     Surname  CreditScore Geography Gender   Age  Tenure  \
# 0  15000  15594796.0         Chu        584.0   Germany   Male  30.0     2.0
# 1  15001  15642821.0       Mazzi        551.0    France   Male  39.0     5.0
# 2  15002  15716284.0   Onyekachi        706.0    France   Male  43.0     8.0
# 3  15003  15785078.0      Martin        717.0     Spain   Male  45.0     3.0
# 4  15004  15662955.0  Kenechukwu        592.0     Spain   Male  43.0     8.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0  146053.66            1.0        1.0             1.0        157891.86
# 1       0.00            2.0        1.0             1.0         67431.28
# 2       0.00            2.0        1.0             0.0        156768.45
# 3       0.00            1.0        1.0             1.0        166909.87
# 4       0.00            2.0        1.0             1.0        143681.97

# %% [markdown]
# ### Random Forest

# %%
test_pred_proba_rf = best_pipeline_rf_opt.predict_proba(test_raw_df)[:, 1]
test_raw_df["Exited_rf"] = test_pred_proba_rf.round(2)
test_raw_df["Exited_rf"].head()
# Out:
# 0    0.36
# 1    0.06
# 2    0.24
# 3    0.82
# 4    0.17
# Name: Exited_rf, dtype: float64

# %%
sample_submission_df = pd.read_csv("downloads/sample_submission.csv")
sample_submission_df["Exited"] = test_raw_df["Exited_rf"]
sample_submission_df.to_csv("downloads/submission_random_forest.csv", index=False)

# %% [markdown]
# ### Gradient Boosting

# %%
test_pred_proba_rf = best_pipeline_gb_opt.predict_proba(test_raw_df)[:, 1]
test_raw_df["Exited_gb"] = test_pred_proba_rf.round(2)
test_raw_df["Exited_gb"].head()
# Out:
# 0    0.10
# 1    0.02
# 2    0.04
# 3    0.50
# 4    0.04
# Name: Exited_gb, dtype: float64

# %%
sample_submission_df = pd.read_csv("downloads/sample_submission.csv")
sample_submission_df["Exited"] = test_raw_df["Exited_gb"]
sample_submission_df.to_csv("downloads/submission_gradientboost.csv", index=False)

# %% [markdown]
# ### Adaboost

# %%
test_pred_proba_ada = best_pipeline_ada_opt.predict_proba(test_raw_df)[:, 1]
test_raw_df["Exited_ada"] = test_pred_proba_ada.round(2)
test_raw_df["Exited_ada"].head()
# Out:
# 0    0.35
# 1    0.24
# 2    0.30
# 3    0.50
# 4    0.28
# Name: Exited_ada, dtype: float64

# %%
sample_submission_df = pd.read_csv("downloads/sample_submission.csv")
sample_submission_df["Exited"] = test_raw_df["Exited_ada"]
sample_submission_df.to_csv("downloads/submission_adaboost.csv", index=False)

# %% [markdown]
# ### XGBoost

# %%
test_pred_proba_xgb = best_pipeline_xgb_opt.predict_proba(test_raw_df)[:, 1]
test_raw_df["Exited_xgb"] = test_pred_proba_xgb.round(2)
test_raw_df["Exited_xgb"].head()
# Out:
# 0    0.08
# 1    0.01
# 2    0.06
# 3    0.49
# 4    0.03
# Name: Exited_xgb, dtype: float32

# %%
sample_submission_df = pd.read_csv("downloads/sample_submission.csv")
sample_submission_df["Exited"] = test_raw_df["Exited_xgb"]
sample_submission_df.to_csv("downloads/submission_xgboost.csv", index=False)

# %% [markdown]
# ### LightGBM

# %%
test_pred_proba_xgb = best_pipeline_lgb_opt.predict_proba(test_raw_df)[:, 1]
test_raw_df["Exited_lgb"] = test_pred_proba_xgb.round(2)
test_raw_df["Exited_lgb"].head()
# Out:
# 0    0.10
# 1    0.02
# 2    0.04
# 3    0.54
# 4    0.03
# Name: Exited_lgb, dtype: float64

# %%
sample_submission_df = pd.read_csv("downloads/sample_submission.csv")
sample_submission_df["Exited"] = test_raw_df["Exited_lgb"]
sample_submission_df.to_csv("downloads/submission_lightgbm.csv", index=False)
